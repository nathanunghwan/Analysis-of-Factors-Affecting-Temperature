# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 588

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    
    city_url =f'{url}&q={city}&appid={weather_api_key}&units=metric'
    response=requests.get(city_url)
    
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
 # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date =city_weather["dt"]
 
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
   
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | havre-saint-pierre
# Processing Record 2 of Set 1 | ambon
# Processing Record 3 of Set 1 | tuktoyaktuk
# Processing Record 4 of Set 1 | souillac
# Processing Record 5 of Set 1 | henties bay
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | hede
# Processing Record 9 of Set 1 | tahta
# Processing Record 10 of Set 1 | cabo san lucas
# Processing Record 11 of Set 1 | abonnema
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | ilulissat
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | nimbahera
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | kirakira
# Processing Record 18 of Set 1 | vardo
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | itarema
# Processing Record 22 of Set 1 | college
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | itacoatiara
# Processing Record 25 of Set 1 | guerrero negro
# Processing Record 26 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 1 | tual
# Processing Record 28 of Set 1 | saltpond
# Processing Record 29 of Set 1 | saint-philippe
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | colares
# Processing Record 34 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 35 of Set 1 | manadhoo
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | komsomolskiy
# Processing Record 38 of Set 1 | provideniya
# Processing Record 39 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 1 | berlevag
# Processing Record 41 of Set 1 | bethel
# Processing Record 42 of Set 1 | sibolga
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | qabis
# City not found. Skipping...
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | touros
# Processing Record 49 of Set 1 | puerto suarez
# Processing Record 50 of Set 1 | codrington
# Processing Record 0 of Set 2 | salekhard
# Processing Record 1 of Set 2 | fethiye
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | fortuna
# Processing Record 4 of Set 2 | arraial do cabo
# Processing Record 5 of Set 2 | ostrovnoy
# Processing Record 6 of Set 2 | severo-kurilsk
# Processing Record 7 of Set 2 | rincon
# Processing Record 8 of Set 2 | oktyabrskoye
# Processing Record 9 of Set 2 | puerto narino
# Processing Record 10 of Set 2 | cidreira
# Processing Record 11 of Set 2 | belyy yar
# Processing Record 12 of Set 2 | vila velha
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | kupang
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | santa rita arriba
# Processing Record 17 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 18 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 2 | nuevo progreso
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | tyup
# Processing Record 23 of Set 2 | salinas
# Processing Record 24 of Set 2 | anadyr
# Processing Record 25 of Set 2 | hami
# Processing Record 26 of Set 2 | iracoubo
# Processing Record 27 of Set 2 | yumen
# Processing Record 28 of Set 2 | ambilobe
# Processing Record 29 of Set 2 | hermanus
# Processing Record 30 of Set 2 | padang
# Processing Record 31 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 32 of Set 2 | torbay
# Processing Record 33 of Set 2 | mitsamiouli
# Processing Record 34 of Set 2 | deputatskiy
# Processing Record 35 of Set 2 | chokurdakh
# Processing Record 36 of Set 2 | wahpeton
# Processing Record 37 of Set 2 | hithadhoo
# Processing Record 38 of Set 2 | bubaque
# Processing Record 39 of Set 2 | lagoa
# Processing Record 40 of Set 2 | chicama
# Processing Record 41 of Set 2 | baherden
# Processing Record 42 of Set 2 | margate
# Processing Record 43 of Set 2 | abu samrah
# Processing Record 44 of Set 2 | longyearbyen
# Processing Record 45 of Set 2 | ancud
# Processing Record 46 of Set 2 | palasa
# Processing Record 47 of Set 2 | khatanga
# Processing Record 48 of Set 2 | leh
# Processing Record 49 of Set 2 | zambezi
# Processing Record 0 of Set 3 | castro
# Processing Record 1 of Set 3 | salalah
# Processing Record 2 of Set 3 | panaba
# Processing Record 3 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 3 | east london
# Processing Record 5 of Set 3 | mount gambier
# Processing Record 6 of Set 3 | vung tau
# Processing Record 7 of Set 3 | nikolskoye
# Processing Record 8 of Set 3 | vanimo
# Processing Record 9 of Set 3 | upernavik
# Processing Record 10 of Set 3 | matveyevka
# Processing Record 11 of Set 3 | raudeberg
# Processing Record 12 of Set 3 | lebu
# Processing Record 13 of Set 3 | kaitangata
# Processing Record 14 of Set 3 | oudtshoorn
# Processing Record 15 of Set 3 | tasiilaq
# Processing Record 16 of Set 3 | nyirabrany
# Processing Record 17 of Set 3 | afsin
# Processing Record 18 of Set 3 | fallon
# Processing Record 19 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 3 | tahe
# Processing Record 21 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 3 | talara
# Processing Record 23 of Set 3 | tiznit
# Processing Record 24 of Set 3 | victoria
# Processing Record 25 of Set 3 | yar-sale
# Processing Record 26 of Set 3 | raga
# Processing Record 27 of Set 3 | carnarvon
# Processing Record 28 of Set 3 | butaritari
# Processing Record 29 of Set 3 | adrar
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | gospic
# Processing Record 32 of Set 3 | san quintin
# Processing Record 33 of Set 3 | kavaratti
# Processing Record 34 of Set 3 | lompoc
# Processing Record 35 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 36 of Set 3 | new norfolk
# Processing Record 37 of Set 3 | mahebourg
# Processing Record 38 of Set 3 | maarianhamina
# Processing Record 39 of Set 3 | clarksdale
# Processing Record 40 of Set 3 | asau
# Processing Record 41 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 42 of Set 3 | kaspiyskiy
# Processing Record 43 of Set 3 | kodiak
# Processing Record 44 of Set 3 | ribeira grande
# Processing Record 45 of Set 3 | thunder bay
# Processing Record 46 of Set 3 | lancaster
# Processing Record 47 of Set 3 | san juan
# Processing Record 48 of Set 3 | namtsy
# Processing Record 49 of Set 3 | saskylakh
# Processing Record 0 of Set 4 | tambura
# Processing Record 1 of Set 4 | seoul
# Processing Record 2 of Set 4 | koulikoro
# Processing Record 3 of Set 4 | santa rosa
# Processing Record 4 of Set 4 | romodanovo
# Processing Record 5 of Set 4 | vila franca do campo
# Processing Record 6 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 4 | tazovskiy
# Processing Record 8 of Set 4 | nome
# Processing Record 9 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 4 | ahipara
# Processing Record 11 of Set 4 | daru
# Processing Record 12 of Set 4 | cairns
# Processing Record 13 of Set 4 | manaus
# Processing Record 14 of Set 4 | fort pierce
# Processing Record 15 of Set 4 | hay river
# Processing Record 16 of Set 4 | pandan
# Processing Record 17 of Set 4 | vostok
# Processing Record 18 of Set 4 | bar-le-duc
# Processing Record 19 of Set 4 | middelburg
# Processing Record 20 of Set 4 | asyut
# Processing Record 21 of Set 4 | barrow
# Processing Record 22 of Set 4 | hobart
# Processing Record 23 of Set 4 | vawkavysk
# Processing Record 24 of Set 4 | lasa
# Processing Record 25 of Set 4 | coari
# Processing Record 26 of Set 4 | tura
# Processing Record 27 of Set 4 | pathalgaon
# Processing Record 28 of Set 4 | narsaq
# Processing Record 29 of Set 4 | tingi
# Processing Record 30 of Set 4 | thompson
# Processing Record 31 of Set 4 | dikson
# Processing Record 32 of Set 4 | mabaruma
# Processing Record 33 of Set 4 | atar
# Processing Record 34 of Set 4 | banda aceh
# Processing Record 35 of Set 4 | matara
# Processing Record 36 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 4 | luderitz
# Processing Record 38 of Set 4 | scottsbluff
# Processing Record 39 of Set 4 | yairipok
# Processing Record 40 of Set 4 | bukavu
# Processing Record 41 of Set 4 | qaqortoq
# Processing Record 42 of Set 4 | saint-joseph
# Processing Record 43 of Set 4 | biratnagar
# Processing Record 44 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 4 | warmbad
# Processing Record 46 of Set 4 | alugan
# Processing Record 47 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 4 | georgetown
# Processing Record 49 of Set 4 | okhotsk
# Processing Record 0 of Set 5 | iquique
# Processing Record 1 of Set 5 | katsuura
# Processing Record 2 of Set 5 | cacequi
# Processing Record 3 of Set 5 | ust-maya
# Processing Record 4 of Set 5 | qaanaaq
# Processing Record 5 of Set 5 | port hardy
# Processing Record 6 of Set 5 | zhigansk
# Processing Record 7 of Set 5 | namibe
# Processing Record 8 of Set 5 | mastic beach
# Processing Record 9 of Set 5 | priargunsk
# Processing Record 10 of Set 5 | nalut
# Processing Record 11 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 5 | bilibino
# Processing Record 13 of Set 5 | kasongo-lunda
# Processing Record 14 of Set 5 | khani
# Processing Record 15 of Set 5 | burkhala
# City not found. Skipping...
# Processing Record 16 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 17 of Set 5 | jinchang
# Processing Record 18 of Set 5 | hasaki
# Processing Record 19 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 5 | karasburg
# Processing Record 21 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 5 | tornio
# Processing Record 23 of Set 5 | jumla
# Processing Record 24 of Set 5 | buraydah
# Processing Record 25 of Set 5 | bambous virieux
# Processing Record 26 of Set 5 | kalaleh
# Processing Record 27 of Set 5 | sayyan
# Processing Record 28 of Set 5 | san lorenzo
# Processing Record 29 of Set 5 | sola
# Processing Record 30 of Set 5 | boa vista
# Processing Record 31 of Set 5 | maniitsoq
# Processing Record 32 of Set 5 | corning
# Processing Record 33 of Set 5 | kununurra
# Processing Record 34 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 35 of Set 5 | stromness
# Processing Record 36 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 5 | korla
# Processing Record 38 of Set 5 | faanui
# Processing Record 39 of Set 5 | los llanos de aridane
# Processing Record 40 of Set 5 | thinadhoo
# Processing Record 41 of Set 5 | turukhansk
# Processing Record 42 of Set 5 | te anau
# Processing Record 43 of Set 5 | ponta delgada
# Processing Record 44 of Set 5 | tateyama
# Processing Record 45 of Set 5 | takoradi
# Processing Record 46 of Set 5 | atbasar
# Processing Record 47 of Set 5 | zandvoort
# Processing Record 48 of Set 5 | iqaluit
# Processing Record 49 of Set 5 | lamu
# Processing Record 0 of Set 6 | santiago del estero
# Processing Record 1 of Set 6 | fort nelson
# Processing Record 2 of Set 6 | kahului
# Processing Record 3 of Set 6 | mingshui
# Processing Record 4 of Set 6 | xining
# Processing Record 5 of Set 6 | nacala
# Processing Record 6 of Set 6 | havoysund
# Processing Record 7 of Set 6 | awjilah
# Processing Record 8 of Set 6 | ketchikan
# Processing Record 9 of Set 6 | perth
# Processing Record 10 of Set 6 | mar del plata
# Processing Record 11 of Set 6 | port blair
# Processing Record 12 of Set 6 | ankang
# Processing Record 13 of Set 6 | canmore
# Processing Record 14 of Set 6 | myaundzha
# Processing Record 15 of Set 6 | cavan
# Processing Record 16 of Set 6 | saint-pierre
# Processing Record 17 of Set 6 | sitka
# Processing Record 18 of Set 6 | salamiyah
# Processing Record 19 of Set 6 | jalu
# Processing Record 20 of Set 6 | divnomorskoye
# Processing Record 21 of Set 6 | necochea
# Processing Record 22 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 6 | san patricio
# Processing Record 24 of Set 6 | aden
# Processing Record 25 of Set 6 | sapao
# City not found. Skipping...
# Processing Record 26 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 28 of Set 6 | geraldton
# Processing Record 29 of Set 6 | sungai petani
# Processing Record 30 of Set 6 | samarai
# Processing Record 31 of Set 6 | avarua
# Processing Record 32 of Set 6 | bonthe
# Processing Record 33 of Set 6 | tromso
# Processing Record 34 of Set 6 | champerico
# Processing Record 35 of Set 6 | mill valley
# Processing Record 36 of Set 6 | leshukonskoye
# Processing Record 37 of Set 6 | la rioja
# Processing Record 38 of Set 6 | tuatapere
# Processing Record 39 of Set 6 | port hueneme
# Processing Record 40 of Set 6 | marzuq
# Processing Record 41 of Set 6 | bengkulu
# Processing Record 42 of Set 6 | aksay
# Processing Record 43 of Set 6 | saint george
# Processing Record 44 of Set 6 | nisia floresta
# Processing Record 45 of Set 6 | ranot
# Processing Record 46 of Set 6 | esperance
# Processing Record 47 of Set 6 | gizo
# Processing Record 48 of Set 6 | norman wells
# Processing Record 49 of Set 6 | alofi
# Processing Record 0 of Set 7 | woodstock
# Processing Record 1 of Set 7 | kamaishi
# Processing Record 2 of Set 7 | jatai
# Processing Record 3 of Set 7 | inhambane
# Processing Record 4 of Set 7 | pesochnoye
# Processing Record 5 of Set 7 | hofn
# Processing Record 6 of Set 7 | kisangani
# Processing Record 7 of Set 7 | vereya
# Processing Record 8 of Set 7 | kichera
# Processing Record 9 of Set 7 | dingle
# Processing Record 10 of Set 7 | nanortalik
# Processing Record 11 of Set 7 | rognan
# Processing Record 12 of Set 7 | mushie
# Processing Record 13 of Set 7 | skagen
# Processing Record 14 of Set 7 | athieme
# City not found. Skipping...
# Processing Record 15 of Set 7 | teya
# Processing Record 16 of Set 7 | teahupoo
# Processing Record 17 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 7 | tres arroyos
# Processing Record 19 of Set 7 | damietta
# Processing Record 20 of Set 7 | marsa matruh
# Processing Record 21 of Set 7 | linguere
# Processing Record 22 of Set 7 | chuy
# Processing Record 23 of Set 7 | broome
# Processing Record 24 of Set 7 | naze
# Processing Record 25 of Set 7 | dhankuta
# Processing Record 26 of Set 7 | prince rupert
# Processing Record 27 of Set 7 | ndola
# Processing Record 28 of Set 7 | phitsanulok
# Processing Record 29 of Set 7 | yulara
# Processing Record 30 of Set 7 | grand gaube
# Processing Record 31 of Set 7 | kamenka
# Processing Record 32 of Set 7 | constitucion
# Processing Record 33 of Set 7 | clarence town
# Processing Record 34 of Set 7 | zhanaozen
# Processing Record 35 of Set 7 | pisco
# Processing Record 36 of Set 7 | cayenne
# Processing Record 37 of Set 7 | mponela
# Processing Record 38 of Set 7 | pringsewu
# Processing Record 39 of Set 7 | port-cartier
# Processing Record 40 of Set 7 | lorengau
# Processing Record 41 of Set 7 | viru
# Processing Record 42 of Set 7 | nkhotakota
# Processing Record 43 of Set 7 | hlatikulu
# Processing Record 44 of Set 7 | mehriz
# Processing Record 45 of Set 7 | mezen
# Processing Record 46 of Set 7 | gao
# Processing Record 47 of Set 7 | leningradskiy
# Processing Record 48 of Set 7 | sao miguel do araguaia
# Processing Record 49 of Set 7 | coria
# Processing Record 0 of Set 8 | lata
# Processing Record 1 of Set 8 | sao filipe
# Processing Record 2 of Set 8 | goundam
# Processing Record 3 of Set 8 | tiksi
# Processing Record 4 of Set 8 | walvis bay
# Processing Record 5 of Set 8 | santa maria
# Processing Record 6 of Set 8 | anchorage
# Processing Record 7 of Set 8 | mount isa
# Processing Record 8 of Set 8 | oxapampa
# Processing Record 9 of Set 8 | vestmannaeyjar
# Processing Record 10 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 11 of Set 8 | onega
# Processing Record 12 of Set 8 | peniche
# Processing Record 13 of Set 8 | naryan-mar
# Processing Record 14 of Set 8 | pokrovsk
# Processing Record 15 of Set 8 | lavrentiya
# Processing Record 16 of Set 8 | jaque
# Processing Record 17 of Set 8 | buchanan
# Processing Record 18 of Set 8 | biltine
# Processing Record 19 of Set 8 | clyde river
# Processing Record 20 of Set 8 | rosarito
# Processing Record 21 of Set 8 | tepalcatepec
# Processing Record 22 of Set 8 | luan
# Processing Record 23 of Set 8 | kruisfontein
# Processing Record 24 of Set 8 | klaksvik
# Processing Record 25 of Set 8 | lovington
# Processing Record 26 of Set 8 | bayir
# Processing Record 27 of Set 8 | lampazos de naranjo
# Processing Record 28 of Set 8 | burica
# City not found. Skipping...
# Processing Record 29 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 30 of Set 8 | osakarovka
# Processing Record 31 of Set 8 | chimore
# Processing Record 32 of Set 8 | saint-denis
# Processing Record 33 of Set 8 | montepuez
# Processing Record 34 of Set 8 | vao
# Processing Record 35 of Set 8 | huilong
# Processing Record 36 of Set 8 | horta
# Processing Record 37 of Set 8 | montague
# Processing Record 38 of Set 8 | hervey bay
# Processing Record 39 of Set 8 | roebourne
# Processing Record 40 of Set 8 | mayo
# Processing Record 41 of Set 8 | itaituba
# Processing Record 42 of Set 8 | mordovo
# Processing Record 43 of Set 8 | zyryanka
# Processing Record 44 of Set 8 | lhuntshi
# City not found. Skipping...
# Processing Record 45 of Set 8 | santa cruz de tenerife
# Processing Record 46 of Set 8 | kyzyl-suu
# Processing Record 47 of Set 8 | kutum
# Processing Record 48 of Set 8 | antofagasta
# Processing Record 49 of Set 8 | rudbar
# Processing Record 0 of Set 9 | polyarnyy
# Processing Record 1 of Set 9 | phan thiet
# Processing Record 2 of Set 9 | nurota
# Processing Record 3 of Set 9 | kuytun
# Processing Record 4 of Set 9 | vega de alatorre
# Processing Record 5 of Set 9 | san pedro
# Processing Record 6 of Set 9 | caravelas
# Processing Record 7 of Set 9 | port macquarie
# Processing Record 8 of Set 9 | avallon
# Processing Record 9 of Set 9 | melendugno
# Processing Record 10 of Set 9 | aklavik
# Processing Record 11 of Set 9 | hirado
# Processing Record 12 of Set 9 | murgab
# Processing Record 13 of Set 9 | opuwo
# Processing Record 14 of Set 9 | amapa
# Processing Record 15 of Set 9 | saldanha
# Processing Record 16 of Set 9 | praia da vitoria
# Processing Record 17 of Set 9 | aketi
# Processing Record 18 of Set 9 | alakurtti
# Processing Record 19 of Set 9 | husavik
# Processing Record 20 of Set 9 | merauke
# Processing Record 21 of Set 9 | buta
# Processing Record 22 of Set 9 | pedernales
# Processing Record 23 of Set 9 | tautira
# Processing Record 24 of Set 9 | sento se
# City not found. Skipping...
# Processing Record 25 of Set 9 | esna
# Processing Record 26 of Set 9 | fairbanks
# Processing Record 27 of Set 9 | cherskiy
# Processing Record 28 of Set 9 | brighton
# Processing Record 29 of Set 9 | gigmoto
# Processing Record 30 of Set 9 | sukumo
# Processing Record 31 of Set 9 | rawson
# Processing Record 32 of Set 9 | volary
# Processing Record 33 of Set 9 | nouadhibou
# Processing Record 34 of Set 9 | markova
# Processing Record 35 of Set 9 | springfield
# Processing Record 36 of Set 9 | pilao arcado
# City not found. Skipping...
# Processing Record 37 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 38 of Set 9 | hambantota
# Processing Record 39 of Set 9 | san cristobal
# Processing Record 40 of Set 9 | kapoeta
# Processing Record 41 of Set 9 | meadow lake
# Processing Record 42 of Set 9 | santa cruz
# Processing Record 43 of Set 9 | xai-xai
# Processing Record 44 of Set 9 | bayan
# Processing Record 45 of Set 9 | los andes
# Processing Record 46 of Set 9 | lao cai
# Processing Record 47 of Set 9 | kamyshevatskaya
# Processing Record 48 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 9 | kawalu
# Processing Record 0 of Set 10 | dniprovka
# Processing Record 1 of Set 10 | ciudad bolivar
# Processing Record 2 of Set 10 | goderich
# Processing Record 3 of Set 10 | port lincoln
# Processing Record 4 of Set 10 | kieta
# Processing Record 5 of Set 10 | grindavik
# Processing Record 6 of Set 10 | skjervoy
# Processing Record 7 of Set 10 | matagami
# Processing Record 8 of Set 10 | bull savanna
# Processing Record 9 of Set 10 | north bend
# Processing Record 10 of Set 10 | olafsvik
# Processing Record 11 of Set 10 | zhangye
# Processing Record 12 of Set 10 | pundaguitan
# Processing Record 13 of Set 10 | suntar
# Processing Record 14 of Set 10 | airai
# Processing Record 15 of Set 10 | beira
# Processing Record 16 of Set 10 | port hedland
# Processing Record 17 of Set 10 | kyabram
# Processing Record 18 of Set 10 | diego de almagro
# Processing Record 19 of Set 10 | tocopilla
# Processing Record 20 of Set 10 | poum
# Processing Record 21 of Set 10 | tomatlan
# Processing Record 22 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 23 of Set 10 | riverton
# Processing Record 24 of Set 10 | pemangkat
# Processing Record 25 of Set 10 | soyo
# Processing Record 26 of Set 10 | quatre cocos
# Processing Record 27 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 28 of Set 10 | sistranda
# Processing Record 29 of Set 10 | ulaanbaatar
# Processing Record 30 of Set 10 | charters towers
# Processing Record 31 of Set 10 | mae sot
# Processing Record 32 of Set 10 | saint-michel-des-saints
# Processing Record 33 of Set 10 | dunmore east
# Processing Record 34 of Set 10 | elizabeth city
# Processing Record 35 of Set 10 | batemans bay
# Processing Record 36 of Set 10 | hit
# Processing Record 37 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 10 | zuwarah
# Processing Record 39 of Set 10 | srandakan
# Processing Record 40 of Set 10 | hamilton
# Processing Record 41 of Set 10 | iberia
# Processing Record 42 of Set 10 | mega
# Processing Record 43 of Set 10 | tvoroyri
# Processing Record 44 of Set 10 | namatanai
# Processing Record 45 of Set 10 | la peca
# Processing Record 46 of Set 10 | bodaybo
# Processing Record 47 of Set 10 | kafue
# Processing Record 48 of Set 10 | kyshtovka
# Processing Record 49 of Set 10 | alta floresta
# Processing Record 0 of Set 11 | jishou
# Processing Record 1 of Set 11 | florianopolis
# Processing Record 2 of Set 11 | kuryk
# Processing Record 3 of Set 11 | saint-georges
# Processing Record 4 of Set 11 | valentin gomez farias
# Processing Record 5 of Set 11 | noumea
# Processing Record 6 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 7 of Set 11 | gazojak
# Processing Record 8 of Set 11 | hobyo
# Processing Record 9 of Set 11 | talnakh
# Processing Record 10 of Set 11 | wanning
# Processing Record 11 of Set 11 | tulum
# Processing Record 12 of Set 11 | groningen
# Processing Record 13 of Set 11 | waddan
# Processing Record 14 of Set 11 | hengshui
# Processing Record 15 of Set 11 | porto novo
# Processing Record 16 of Set 11 | haines junction
# Processing Record 17 of Set 11 | srednekolymsk
# Processing Record 18 of Set 11 | bambanglipuro
# Processing Record 19 of Set 11 | la ronge
# Processing Record 20 of Set 11 | mehamn
# Processing Record 21 of Set 11 | pinsk
# Processing Record 22 of Set 11 | goure
# Processing Record 23 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 11 | petrila
# Processing Record 25 of Set 11 | uzunkopru
# City not found. Skipping...
# Processing Record 26 of Set 11 | springbok
# Processing Record 27 of Set 11 | dubbo
# Processing Record 28 of Set 11 | isangel
# Processing Record 29 of Set 11 | sakaiminato
# Processing Record 30 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 11 | sabang
# Processing Record 32 of Set 11 | katav-ivanovsk
# Processing Record 33 of Set 11 | saint anthony
# Processing Record 34 of Set 11 | paka
# Processing Record 35 of Set 11 | wichita falls
# Processing Record 36 of Set 11 | columbus
# Processing Record 37 of Set 11 | sao felix do xingu
# Processing Record 38 of Set 11 | northam
# Processing Record 39 of Set 11 | vaitape
# Processing Record 40 of Set 11 | kimberley
# Processing Record 41 of Set 11 | francistown
# Processing Record 42 of Set 11 | trinidad
# Processing Record 43 of Set 11 | mancio lima
# Processing Record 44 of Set 11 | itacare
# Processing Record 45 of Set 11 | guiglo
# Processing Record 46 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 47 of Set 11 | barcelona
# Processing Record 48 of Set 11 | carballo
# Processing Record 49 of Set 11 | kangaatsiaq
# Processing Record 0 of Set 12 | tezu
# Processing Record 1 of Set 12 | dustlik
# Processing Record 2 of Set 12 | pevek
# Processing Record 3 of Set 12 | teguldet
# Processing Record 4 of Set 12 | dunedin
# Processing Record 5 of Set 12 | cap malheureux
# Processing Record 6 of Set 12 | canico
# Processing Record 7 of Set 12 | pangnirtung
# Processing Record 8 of Set 12 | kloulklubed
# Processing Record 9 of Set 12 | avera
# Processing Record 10 of Set 12 | korem
# Processing Record 11 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 12 | diffa
# Processing Record 13 of Set 12 | lufilufi
# Processing Record 14 of Set 12 | innisfail
# Processing Record 15 of Set 12 | abu kamal
# Processing Record 16 of Set 12 | bandarbeyla
# Processing Record 17 of Set 12 | portland
# Processing Record 18 of Set 12 | basco
# Processing Record 19 of Set 12 | carutapera
# Processing Record 20 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 21 of Set 12 | ayabaca
# Processing Record 22 of Set 12 | yerbogachen
# Processing Record 23 of Set 12 | kantang
# Processing Record 24 of Set 12 | macaboboni
# City not found. Skipping...
# Processing Record 25 of Set 12 | glenluce
# Processing Record 26 of Set 12 | coquimbo
# Processing Record 27 of Set 12 | nishihara
# Processing Record 28 of Set 12 | the pas
# Processing Record 29 of Set 12 | santo antonio do sudoeste
# Processing Record 30 of Set 12 | novyy urengoy
# Processing Record 31 of Set 12 | boueni
# Processing Record 32 of Set 12 | beringovskiy
# Processing Record 33 of Set 12 | kommunar
# Processing Record 34 of Set 12 | gusau
# Processing Record 35 of Set 12 | nhulunbuy
# Processing Record 36 of Set 12 | ballina
# Processing Record 37 of Set 12 | nguiu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          535
# Lat           535
# Lng           535
# Max Temp      535
# Humidity      535
# Cloudiness    535
# Wind Speed    535
# Country       535
# Date          535
# dtype: int64

# %%
# Display sample data                      
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  havre-saint-pierre  50.2334  -63.5986     -9.00        78           0
# 1               ambon  -3.6954  128.1814     25.08        88          40
# 2         tuktoyaktuk  69.4541 -133.0374    -23.76        95         100
# 3            souillac -20.5167   57.5167     27.21        78          75
# 4         henties bay -22.1160   14.2845     20.52        77          35
#
#    Wind Speed Country        Date
# 0        1.54      CA  1674395251
# 1        2.06      ID  1674395252
# 2        1.70      CA  1674395252
# 3        5.14      MU  1674395253
# 4        4.81      NA  1674395253

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

#Convert Date by Using pandas to_datetime
city_data_df['Date']= pd.to_datetime(city_data_df['Date'],unit='s').dt.strftime('%Y-%m-%d %H:%M')  

# Display sample data
city_data_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        havre-saint-pierre  50.2334  -63.5986     -9.00        78
# 1                     ambon  -3.6954  128.1814     25.08        88
# 2               tuktoyaktuk  69.4541 -133.0374    -23.76        95
# 3                  souillac -20.5167   57.5167     27.21        78
# 4               henties bay -22.1160   14.2845     20.52        77
#
#          Cloudiness  Wind Speed Country              Date
# City_ID
# 0                 0        1.54      CA  2023-01-22 13:47
# 1                40        2.06      ID  2023-01-22 13:47
# 2               100        1.70      CA  2023-01-22 13:47
# 3                75        5.14      MU  2023-01-22 13:47
# 4                35        4.81     NaN  2023-01-22 13:47

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'],edgecolors="black",facecolors="steelblue")
plt.grid()
plt.title("City Max Latitude vs. Temperature (2023-01-22)",fontsize=13)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
plt.savefig("output_data/Fig1.png")
# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 4
#       2 plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'],edgecolors="black",facecolors="steelblue")
#       3 plt.grid()
# ----> 4 plt.title("City Max Latitude vs. Temperature (2023-01-22)",fontsize=13)
#       5 plt.xlabel("Latitude")
#       6 plt.ylabel("Max Temperature(C)")
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# Incorporate the other graph properties

plt.scatter(city_data_df['Lat'],city_data_df['Humidity'],edgecolors="black",facecolors="steelblue")
plt.grid()
plt.title("City Latitude vs. Humidity (2023-01-22)",fontsize=13)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 6
#       4 plt.scatter(city_data_df['Lat'],city_data_df['Humidity'],edgecolors="black",facecolors="steelblue")
#       5 plt.grid()
# ----> 6 plt.title("City Latitude vs. Humidity (2023-01-22)",fontsize=13)
#       7 plt.xlabel("Latitude")
#       8 plt.ylabel("Humidity (%)")
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'],edgecolors="black",facecolors="steelblue")
plt.grid()
plt.title("City Latitude vs. Cloudiness (2023-01-22)",fontsize=13)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 4
#       2 plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'],edgecolors="black",facecolors="steelblue")
#       3 plt.grid()
# ----> 4 plt.title("City Latitude vs. Cloudiness (2023-01-22)",fontsize=13)
#       5 plt.xlabel("Latitude")
#       6 plt.ylabel("Cloudiness (%)")
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'],edgecolors="black",facecolors="steelblue")
plt.grid()
plt.title("City Latitude vs. Wind Speed (2023-01-22)",fontsize=13)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 4
#       2 plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'],edgecolors="black",facecolors="steelblue")
#       3 plt.grid()
# ----> 4 plt.title("City Latitude vs. Wind Speed (2023-01-22)",fontsize=13)
#       5 plt.xlabel("Latitude")
#       6 plt.ylabel("Wind Speed (m/s)")
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
