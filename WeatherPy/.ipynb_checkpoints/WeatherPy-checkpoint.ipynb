# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

import datetime
import scipy.stats as st
# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 628

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    
    city_url =f'{url}&q={city}&appid={weather_api_key}&units=metric'
    response=requests.get(city_url)
    
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
 # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date =city_weather["dt"]
 
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
   
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | talnakh
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | sorland
# Processing Record 5 of Set 1 | rawson
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | tezu
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | clyde river
# Processing Record 13 of Set 1 | upernavik
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | aksu
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | lompoc
# Processing Record 18 of Set 1 | lorengau
# Processing Record 19 of Set 1 | mustafabad
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | acapulco
# Processing Record 22 of Set 1 | maldonado
# Processing Record 23 of Set 1 | baker city
# Processing Record 24 of Set 1 | kruisfontein
# Processing Record 25 of Set 1 | khatanga
# Processing Record 26 of Set 1 | hambantota
# Processing Record 27 of Set 1 | oksfjord
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | kitimat
# Processing Record 30 of Set 1 | namatanai
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | iqaluit
# Processing Record 34 of Set 1 | muros
# Processing Record 35 of Set 1 | tura
# Processing Record 36 of Set 1 | ugoofaaru
# Processing Record 37 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 1 | esperance
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | aksha
# Processing Record 41 of Set 1 | vanimo
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | loandjili
# Processing Record 44 of Set 1 | stephenville
# Processing Record 45 of Set 1 | boa vista
# Processing Record 46 of Set 1 | tucupita
# Processing Record 47 of Set 1 | carutapera
# Processing Record 48 of Set 1 | avera
# Processing Record 49 of Set 1 | cap malheureux
# Processing Record 50 of Set 1 | asau
# Processing Record 0 of Set 2 | port-cartier
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | portalegre
# Processing Record 3 of Set 2 | nanortalik
# Processing Record 4 of Set 2 | pisco
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | kiruna
# Processing Record 7 of Set 2 | ahipara
# Processing Record 8 of Set 2 | bila tserkva
# Processing Record 9 of Set 2 | narayanganj
# Processing Record 10 of Set 2 | hirara
# Processing Record 11 of Set 2 | chauk
# Processing Record 12 of Set 2 | semnan
# Processing Record 13 of Set 2 | saskylakh
# Processing Record 14 of Set 2 | severo-kurilsk
# Processing Record 15 of Set 2 | mattru
# Processing Record 16 of Set 2 | cabedelo
# Processing Record 17 of Set 2 | sivaki
# Processing Record 18 of Set 2 | orzhytsya
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | meulaboh
# Processing Record 21 of Set 2 | abnub
# Processing Record 22 of Set 2 | ngunguru
# Processing Record 23 of Set 2 | urusha
# Processing Record 24 of Set 2 | atuona
# Processing Record 25 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 2 | bengkulu
# Processing Record 27 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 2 | vung tau
# Processing Record 29 of Set 2 | riverton
# Processing Record 30 of Set 2 | georgetown
# Processing Record 31 of Set 2 | iranshahr
# Processing Record 32 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 2 | namibe
# Processing Record 34 of Set 2 | klaksvik
# Processing Record 35 of Set 2 | constitucion
# Processing Record 36 of Set 2 | aklavik
# Processing Record 37 of Set 2 | cabo san lucas
# Processing Record 38 of Set 2 | lensk
# Processing Record 39 of Set 2 | ust-nera
# Processing Record 40 of Set 2 | auki
# Processing Record 41 of Set 2 | pangkalanbuun
# Processing Record 42 of Set 2 | provideniya
# Processing Record 43 of Set 2 | padang
# Processing Record 44 of Set 2 | taksimo
# Processing Record 45 of Set 2 | shipitsyno
# Processing Record 46 of Set 2 | mount gambier
# Processing Record 47 of Set 2 | tuktoyaktuk
# Processing Record 48 of Set 2 | victoria
# Processing Record 49 of Set 2 | verkh-suetka
# Processing Record 0 of Set 3 | nouakchott
# Processing Record 1 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | castro
# Processing Record 4 of Set 3 | hobart
# Processing Record 5 of Set 3 | college
# Processing Record 6 of Set 3 | stokmarknes
# Processing Record 7 of Set 3 | belousovka
# Processing Record 8 of Set 3 | baykit
# Processing Record 9 of Set 3 | moussoro
# Processing Record 10 of Set 3 | elbrus
# Processing Record 11 of Set 3 | koran
# Processing Record 12 of Set 3 | hobyo
# Processing Record 13 of Set 3 | yellowknife
# Processing Record 14 of Set 3 | batagay-alyta
# Processing Record 15 of Set 3 | new norfolk
# Processing Record 16 of Set 3 | albany
# Processing Record 17 of Set 3 | kaitangata
# Processing Record 18 of Set 3 | ormara
# Processing Record 19 of Set 3 | berlevag
# Processing Record 20 of Set 3 | deputatskiy
# Processing Record 21 of Set 3 | gimbi
# Processing Record 22 of Set 3 | tabas
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | jaguey grande
# Processing Record 25 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 3 | lavrentiya
# Processing Record 27 of Set 3 | komsomolskiy
# Processing Record 28 of Set 3 | bria
# Processing Record 29 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 30 of Set 3 | shelburne
# Processing Record 31 of Set 3 | bethel
# Processing Record 32 of Set 3 | yumen
# Processing Record 33 of Set 3 | cherskiy
# Processing Record 34 of Set 3 | yenagoa
# Processing Record 35 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 36 of Set 3 | barinas
# Processing Record 37 of Set 3 | cockburn town
# Processing Record 38 of Set 3 | east london
# Processing Record 39 of Set 3 | sampit
# Processing Record 40 of Set 3 | torbay
# Processing Record 41 of Set 3 | sur
# Processing Record 42 of Set 3 | faanui
# Processing Record 43 of Set 3 | jiaozuo
# Processing Record 44 of Set 3 | chokurdakh
# Processing Record 45 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 3 | nikolskoye
# Processing Record 47 of Set 3 | airai
# Processing Record 48 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 3 | halifax
# Processing Record 0 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 4 | coracao de jesus
# Processing Record 2 of Set 4 | miri
# Processing Record 3 of Set 4 | kokkola
# Processing Record 4 of Set 4 | moose factory
# Processing Record 5 of Set 4 | onguday
# Processing Record 6 of Set 4 | west wendover
# Processing Record 7 of Set 4 | kostroma
# Processing Record 8 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 9 of Set 4 | arlit
# Processing Record 10 of Set 4 | soyo
# Processing Record 11 of Set 4 | saint-gaudens
# Processing Record 12 of Set 4 | gariadhar
# Processing Record 13 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 14 of Set 4 | nelson bay
# Processing Record 15 of Set 4 | gushikawa
# Processing Record 16 of Set 4 | hami
# Processing Record 17 of Set 4 | bereda
# Processing Record 18 of Set 4 | omidiyeh
# Processing Record 19 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 4 | canico
# Processing Record 22 of Set 4 | vestmanna
# Processing Record 23 of Set 4 | bandarbeyla
# Processing Record 24 of Set 4 | limbang
# Processing Record 25 of Set 4 | balkanabat
# Processing Record 26 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 28 of Set 4 | lagoa
# Processing Record 29 of Set 4 | hokitika
# Processing Record 30 of Set 4 | egvekinot
# Processing Record 31 of Set 4 | gurgan
# City not found. Skipping...
# Processing Record 32 of Set 4 | chuy
# Processing Record 33 of Set 4 | sayyan
# Processing Record 34 of Set 4 | geraldton
# Processing Record 35 of Set 4 | cassilandia
# Processing Record 36 of Set 4 | codrington
# Processing Record 37 of Set 4 | ayr
# Processing Record 38 of Set 4 | pundaguitan
# Processing Record 39 of Set 4 | pevek
# Processing Record 40 of Set 4 | dongsheng
# Processing Record 41 of Set 4 | shetpe
# Processing Record 42 of Set 4 | carnarvon
# Processing Record 43 of Set 4 | vitim
# Processing Record 44 of Set 4 | kaeo
# Processing Record 45 of Set 4 | saint-francois
# Processing Record 46 of Set 4 | sao filipe
# Processing Record 47 of Set 4 | lasa
# Processing Record 48 of Set 4 | hagenow
# Processing Record 49 of Set 4 | arraial do cabo
# Processing Record 0 of Set 5 | bambous virieux
# Processing Record 1 of Set 5 | lakes entrance
# Processing Record 2 of Set 5 | goderich
# Processing Record 3 of Set 5 | mar del plata
# Processing Record 4 of Set 5 | corowa
# Processing Record 5 of Set 5 | moron
# Processing Record 6 of Set 5 | vezirkopru
# Processing Record 7 of Set 5 | sioux lookout
# Processing Record 8 of Set 5 | tahe
# Processing Record 9 of Set 5 | puerto escondido
# Processing Record 10 of Set 5 | junction city
# Processing Record 11 of Set 5 | villarrica
# Processing Record 12 of Set 5 | north platte
# Processing Record 13 of Set 5 | qaanaaq
# Processing Record 14 of Set 5 | kawalu
# Processing Record 15 of Set 5 | kahului
# Processing Record 16 of Set 5 | ribeira grande
# Processing Record 17 of Set 5 | belaya gora
# Processing Record 18 of Set 5 | kuala terengganu
# Processing Record 19 of Set 5 | cape town
# Processing Record 20 of Set 5 | delcevo
# Processing Record 21 of Set 5 | vrangel
# Processing Record 22 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 5 | naze
# Processing Record 24 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 5 | sept-iles
# Processing Record 26 of Set 5 | kerki
# City not found. Skipping...
# Processing Record 27 of Set 5 | salinopolis
# Processing Record 28 of Set 5 | horsham
# Processing Record 29 of Set 5 | requena
# Processing Record 30 of Set 5 | ho
# City not found. Skipping...
# Processing Record 31 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 5 | santiago
# Processing Record 33 of Set 5 | marrakesh
# Processing Record 34 of Set 5 | pushkinskiye gory
# Processing Record 35 of Set 5 | touros
# Processing Record 36 of Set 5 | tutoia
# Processing Record 37 of Set 5 | sokol
# Processing Record 38 of Set 5 | buala
# Processing Record 39 of Set 5 | salalah
# Processing Record 40 of Set 5 | saint-georges
# Processing Record 41 of Set 5 | ostersund
# Processing Record 42 of Set 5 | katokhi
# City not found. Skipping...
# Processing Record 43 of Set 5 | saint anthony
# Processing Record 44 of Set 5 | santa cruz cabralia
# Processing Record 45 of Set 5 | souillac
# Processing Record 46 of Set 5 | kaitong
# Processing Record 47 of Set 5 | acari
# Processing Record 48 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 5 | momcilgrad
# City not found. Skipping...
# Processing Record 0 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 6 | mangla
# Processing Record 2 of Set 6 | pingzhuang
# Processing Record 3 of Set 6 | vilhena
# Processing Record 4 of Set 6 | champerico
# Processing Record 5 of Set 6 | tete
# Processing Record 6 of Set 6 | kangaatsiaq
# Processing Record 7 of Set 6 | puerto leguizamo
# Processing Record 8 of Set 6 | coquimbo
# Processing Record 9 of Set 6 | meridian
# Processing Record 10 of Set 6 | savannakhet
# Processing Record 11 of Set 6 | dukat
# Processing Record 12 of Set 6 | ponta do sol
# Processing Record 13 of Set 6 | butaritari
# Processing Record 14 of Set 6 | nome
# Processing Record 15 of Set 6 | pindushi
# Processing Record 16 of Set 6 | abalak
# Processing Record 17 of Set 6 | safranbolu
# Processing Record 18 of Set 6 | sao felix do xingu
# Processing Record 19 of Set 6 | sao pedro
# Processing Record 20 of Set 6 | puno
# Processing Record 21 of Set 6 | thurso
# Processing Record 22 of Set 6 | russell
# Processing Record 23 of Set 6 | eureka
# Processing Record 24 of Set 6 | guerrero negro
# Processing Record 25 of Set 6 | hamina
# Processing Record 26 of Set 6 | mahebourg
# Processing Record 27 of Set 6 | teya
# Processing Record 28 of Set 6 | palana
# Processing Record 29 of Set 6 | bathsheba
# Processing Record 30 of Set 6 | palmer
# Processing Record 31 of Set 6 | ilulissat
# Processing Record 32 of Set 6 | hasaki
# Processing Record 33 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 6 | mareeba
# Processing Record 35 of Set 6 | chifeng
# Processing Record 36 of Set 6 | bilibino
# Processing Record 37 of Set 6 | jua
# Processing Record 38 of Set 6 | katsuura
# Processing Record 39 of Set 6 | pleasanton
# Processing Record 40 of Set 6 | belyy yar
# Processing Record 41 of Set 6 | chemal
# Processing Record 42 of Set 6 | ambilobe
# Processing Record 43 of Set 6 | oistins
# Processing Record 44 of Set 6 | larnaca
# Processing Record 45 of Set 6 | dulyapino
# Processing Record 46 of Set 6 | tokomaru
# Processing Record 47 of Set 6 | vallenar
# Processing Record 48 of Set 6 | marawi
# Processing Record 49 of Set 6 | ullapool
# Processing Record 0 of Set 7 | fortuna
# Processing Record 1 of Set 7 | bonfim
# Processing Record 2 of Set 7 | yabrud
# Processing Record 3 of Set 7 | oranjemund
# Processing Record 4 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 5 of Set 7 | saint george
# Processing Record 6 of Set 7 | pinawa
# Processing Record 7 of Set 7 | kysyl-syr
# Processing Record 8 of Set 7 | kailua
# Processing Record 9 of Set 7 | sortavala
# Processing Record 10 of Set 7 | japura
# Processing Record 11 of Set 7 | port macquarie
# Processing Record 12 of Set 7 | ostrovnoy
# Processing Record 13 of Set 7 | san andres
# Processing Record 14 of Set 7 | hecun
# Processing Record 15 of Set 7 | yambio
# Processing Record 16 of Set 7 | sanchor
# Processing Record 17 of Set 7 | talas
# Processing Record 18 of Set 7 | lebu
# Processing Record 19 of Set 7 | novo aripuana
# Processing Record 20 of Set 7 | betanzos
# Processing Record 21 of Set 7 | sarkand
# Processing Record 22 of Set 7 | portland
# Processing Record 23 of Set 7 | grafton
# Processing Record 24 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 7 | san patricio
# Processing Record 26 of Set 7 | beloha
# Processing Record 27 of Set 7 | olinda
# Processing Record 28 of Set 7 | benjamin constant
# Processing Record 29 of Set 7 | lahuachaca
# Processing Record 30 of Set 7 | athens
# Processing Record 31 of Set 7 | alofi
# Processing Record 32 of Set 7 | banda aceh
# Processing Record 33 of Set 7 | upata
# Processing Record 34 of Set 7 | pingdingshan
# Processing Record 35 of Set 7 | cairns
# Processing Record 36 of Set 7 | iralaya
# Processing Record 37 of Set 7 | emerald
# Processing Record 38 of Set 7 | yuryevets
# Processing Record 39 of Set 7 | izvestkovyy
# Processing Record 40 of Set 7 | vardo
# Processing Record 41 of Set 7 | aswan
# Processing Record 42 of Set 7 | san joaquin
# Processing Record 43 of Set 7 | cidreira
# Processing Record 44 of Set 7 | kenai
# Processing Record 45 of Set 7 | inirida
# Processing Record 46 of Set 7 | aasiaat
# Processing Record 47 of Set 7 | comacchio
# Processing Record 48 of Set 7 | zhezkazgan
# Processing Record 49 of Set 7 | abu samrah
# Processing Record 0 of Set 8 | jabinyanah
# Processing Record 1 of Set 8 | labuhan
# Processing Record 2 of Set 8 | dikson
# Processing Record 3 of Set 8 | aranos
# Processing Record 4 of Set 8 | chippewa falls
# Processing Record 5 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 8 | longyearbyen
# Processing Record 7 of Set 8 | lake havasu city
# Processing Record 8 of Set 8 | artyom
# Processing Record 9 of Set 8 | panan
# Processing Record 10 of Set 8 | muskegon
# Processing Record 11 of Set 8 | teahupoo
# Processing Record 12 of Set 8 | wasilla
# Processing Record 13 of Set 8 | alice springs
# Processing Record 14 of Set 8 | saldanha
# Processing Record 15 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 8 | vaovai
# City not found. Skipping...
# Processing Record 17 of Set 8 | port augusta
# Processing Record 18 of Set 8 | ancud
# Processing Record 19 of Set 8 | half moon bay
# Processing Record 20 of Set 8 | veletma
# City not found. Skipping...
# Processing Record 21 of Set 8 | tiksi
# Processing Record 22 of Set 8 | rolla
# Processing Record 23 of Set 8 | saint-philippe
# Processing Record 24 of Set 8 | pangnirtung
# Processing Record 25 of Set 8 | asyut
# Processing Record 26 of Set 8 | tokonou
# Processing Record 27 of Set 8 | manoel urbano
# Processing Record 28 of Set 8 | bismarck
# Processing Record 29 of Set 8 | bardiyah
# Processing Record 30 of Set 8 | mackenzie
# Processing Record 31 of Set 8 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 32 of Set 8 | kavieng
# Processing Record 33 of Set 8 | chikwawa
# Processing Record 34 of Set 8 | stornoway
# Processing Record 35 of Set 8 | vila franca do campo
# Processing Record 36 of Set 8 | flinders
# Processing Record 37 of Set 8 | leningradskiy
# Processing Record 38 of Set 8 | hattiesburg
# Processing Record 39 of Set 8 | pocatello
# Processing Record 40 of Set 8 | olafsvik
# Processing Record 41 of Set 8 | hovd
# Processing Record 42 of Set 8 | awbari
# Processing Record 43 of Set 8 | morehead
# Processing Record 44 of Set 8 | iskateley
# Processing Record 45 of Set 8 | burnie
# Processing Record 46 of Set 8 | itabera
# Processing Record 47 of Set 8 | gilazi
# City not found. Skipping...
# Processing Record 48 of Set 8 | vila velha
# Processing Record 49 of Set 8 | gravdal
# Processing Record 0 of Set 9 | aktanysh
# Processing Record 1 of Set 9 | uyuni
# Processing Record 2 of Set 9 | comodoro rivadavia
# Processing Record 3 of Set 9 | newport
# Processing Record 4 of Set 9 | moree
# Processing Record 5 of Set 9 | nouadhibou
# Processing Record 6 of Set 9 | hsintien
# City not found. Skipping...
# Processing Record 7 of Set 9 | turayf
# Processing Record 8 of Set 9 | inuvik
# Processing Record 9 of Set 9 | anchorage
# Processing Record 10 of Set 9 | monrovia
# Processing Record 11 of Set 9 | nioro
# Processing Record 12 of Set 9 | basoko
# Processing Record 13 of Set 9 | dubbo
# Processing Record 14 of Set 9 | gorontalo
# Processing Record 15 of Set 9 | kudahuvadhoo
# Processing Record 16 of Set 9 | marzuq
# Processing Record 17 of Set 9 | haines junction
# Processing Record 18 of Set 9 | ferguson
# Processing Record 19 of Set 9 | rio grande
# Processing Record 20 of Set 9 | yaguajay
# Processing Record 21 of Set 9 | kyshtovka
# Processing Record 22 of Set 9 | bacalar
# Processing Record 23 of Set 9 | longjiang
# Processing Record 24 of Set 9 | zaraza
# Processing Record 25 of Set 9 | te anau
# Processing Record 26 of Set 9 | novikovo
# Processing Record 27 of Set 9 | cam pha
# City not found. Skipping...
# Processing Record 28 of Set 9 | waingapu
# Processing Record 29 of Set 9 | bombay
# Processing Record 30 of Set 9 | paita
# Processing Record 31 of Set 9 | bull savanna
# Processing Record 32 of Set 9 | saint-pierre
# Processing Record 33 of Set 9 | kirensk
# Processing Record 34 of Set 9 | katerero
# Processing Record 35 of Set 9 | dzerzhinsk
# Processing Record 36 of Set 9 | labuan
# Processing Record 37 of Set 9 | promyshlennaya
# Processing Record 38 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 9 | husavik
# Processing Record 41 of Set 9 | izumo
# Processing Record 42 of Set 9 | marsa matruh
# Processing Record 43 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 9 | bagdarin
# Processing Record 45 of Set 9 | progreso
# Processing Record 46 of Set 9 | kon tum
# Processing Record 47 of Set 9 | bideford
# Processing Record 48 of Set 9 | anloga
# Processing Record 49 of Set 9 | skibbereen
# Processing Record 0 of Set 10 | peachland
# Processing Record 1 of Set 10 | margate
# Processing Record 2 of Set 10 | linhares
# Processing Record 3 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 4 of Set 10 | walvis bay
# Processing Record 5 of Set 10 | porto novo
# Processing Record 6 of Set 10 | kombissiri
# Processing Record 7 of Set 10 | qaqortoq
# Processing Record 8 of Set 10 | ferme-neuve
# Processing Record 9 of Set 10 | porto walter
# Processing Record 10 of Set 10 | amahai
# Processing Record 11 of Set 10 | yerbogachen
# Processing Record 12 of Set 10 | chandbali
# Processing Record 13 of Set 10 | batsfjord
# Processing Record 14 of Set 10 | khasan
# Processing Record 15 of Set 10 | chumikan
# Processing Record 16 of Set 10 | byron bay
# Processing Record 17 of Set 10 | khash
# Processing Record 18 of Set 10 | vanavara
# Processing Record 19 of Set 10 | raudeberg
# Processing Record 20 of Set 10 | gat
# Processing Record 21 of Set 10 | khagaria
# Processing Record 22 of Set 10 | saint-joseph
# Processing Record 23 of Set 10 | chapais
# Processing Record 24 of Set 10 | rognan
# Processing Record 25 of Set 10 | lufkin
# Processing Record 26 of Set 10 | himeji
# Processing Record 27 of Set 10 | akyab
# Processing Record 28 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 29 of Set 10 | huanuco
# Processing Record 30 of Set 10 | santa maria
# Processing Record 31 of Set 10 | norman wells
# Processing Record 32 of Set 10 | tabulbah
# City not found. Skipping...
# Processing Record 33 of Set 10 | kaseda
# Processing Record 34 of Set 10 | luanda
# Processing Record 35 of Set 10 | baracoa
# Processing Record 36 of Set 10 | ryotsu
# Processing Record 37 of Set 10 | maniitsoq
# Processing Record 38 of Set 10 | cubara
# Processing Record 39 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 10 | maraa
# Processing Record 41 of Set 10 | yulara
# Processing Record 42 of Set 10 | manta
# Processing Record 43 of Set 10 | uglovskoye
# Processing Record 44 of Set 10 | bairiki
# Processing Record 45 of Set 10 | kisangani
# Processing Record 46 of Set 10 | puerto carreno
# Processing Record 47 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 10 | tottori
# Processing Record 49 of Set 10 | banepa
# Processing Record 0 of Set 11 | basudebpur
# Processing Record 1 of Set 11 | campiglia marittima
# Processing Record 2 of Set 11 | kyra
# Processing Record 3 of Set 11 | grand gaube
# Processing Record 4 of Set 11 | posse
# Processing Record 5 of Set 11 | pousat
# City not found. Skipping...
# Processing Record 6 of Set 11 | siguiri
# Processing Record 7 of Set 11 | lata
# Processing Record 8 of Set 11 | york
# Processing Record 9 of Set 11 | palauig
# Processing Record 10 of Set 11 | kodinsk
# Processing Record 11 of Set 11 | cayenne
# Processing Record 12 of Set 11 | mahibadhoo
# Processing Record 13 of Set 11 | itacare
# Processing Record 14 of Set 11 | san antonio
# Processing Record 15 of Set 11 | sitka
# Processing Record 16 of Set 11 | manggar
# Processing Record 17 of Set 11 | aiken
# Processing Record 18 of Set 11 | los llanos de aridane
# Processing Record 19 of Set 11 | urumqi
# Processing Record 20 of Set 11 | jadu
# Processing Record 21 of Set 11 | tuatapere
# Processing Record 22 of Set 11 | zhigansk
# Processing Record 23 of Set 11 | kununurra
# Processing Record 24 of Set 11 | tunxi
# City not found. Skipping...
# Processing Record 25 of Set 11 | lucapa
# Processing Record 26 of Set 11 | ojinaga
# Processing Record 27 of Set 11 | perelyub
# Processing Record 28 of Set 11 | diapaga
# Processing Record 29 of Set 11 | seoul
# Processing Record 30 of Set 11 | timizart
# Processing Record 31 of Set 11 | creel
# Processing Record 32 of Set 11 | south sioux city
# Processing Record 33 of Set 11 | taoudenni
# Processing Record 34 of Set 11 | camabatela
# Processing Record 35 of Set 11 | nemuro
# Processing Record 36 of Set 11 | nuqui
# Processing Record 37 of Set 11 | kushiro
# Processing Record 38 of Set 11 | muisne
# Processing Record 39 of Set 11 | sulangan
# Processing Record 40 of Set 11 | santiago del estero
# Processing Record 41 of Set 11 | doha
# Processing Record 42 of Set 11 | copiapo
# Processing Record 43 of Set 11 | siocon
# Processing Record 44 of Set 11 | kodiak
# Processing Record 45 of Set 11 | barda
# Processing Record 46 of Set 11 | tabou
# Processing Record 47 of Set 11 | rohnert park
# Processing Record 48 of Set 11 | san quintin
# Processing Record 49 of Set 11 | arvika
# Processing Record 0 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 1 of Set 12 | jijiga
# Processing Record 2 of Set 12 | rapid valley
# Processing Record 3 of Set 12 | kitaibaraki
# Processing Record 4 of Set 12 | pacific grove
# Processing Record 5 of Set 12 | concordia
# Processing Record 6 of Set 12 | itoman
# Processing Record 7 of Set 12 | roald
# Processing Record 8 of Set 12 | keffi
# Processing Record 9 of Set 12 | mokhsogollokh
# Processing Record 10 of Set 12 | dicabisagan
# Processing Record 11 of Set 12 | bilma
# Processing Record 12 of Set 12 | biak
# Processing Record 13 of Set 12 | gwadar
# Processing Record 14 of Set 12 | nizhniy ingash
# Processing Record 15 of Set 12 | bakchar
# Processing Record 16 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 17 of Set 12 | rocha
# Processing Record 18 of Set 12 | broome
# Processing Record 19 of Set 12 | yerofey pavlovich
# Processing Record 20 of Set 12 | dunedin
# Processing Record 21 of Set 12 | vestmannaeyjar
# Processing Record 22 of Set 12 | tautira
# Processing Record 23 of Set 12 | pauini
# Processing Record 24 of Set 12 | port hedland
# Processing Record 25 of Set 12 | fomboni
# Processing Record 26 of Set 12 | marsh harbour
# Processing Record 27 of Set 12 | nizhneudinsk
# Processing Record 28 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 29 of Set 12 | la ronge
# Processing Record 30 of Set 12 | corn island
# Processing Record 31 of Set 12 | karratha
# Processing Record 32 of Set 12 | pyrzyce
# Processing Record 33 of Set 12 | makakilo city
# Processing Record 34 of Set 12 | icod de los vinos
# Processing Record 35 of Set 12 | loughborough
# Processing Record 36 of Set 12 | san cristobal
# Processing Record 37 of Set 12 | vostok
# Processing Record 38 of Set 12 | mayumba
# Processing Record 39 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 40 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 12 | mehamn
# Processing Record 42 of Set 12 | tamworth
# Processing Record 43 of Set 12 | morros
# Processing Record 44 of Set 12 | fangshan
# Processing Record 45 of Set 12 | dickinson
# Processing Record 46 of Set 12 | jining
# Processing Record 47 of Set 12 | teluknaga
# Processing Record 48 of Set 12 | kieta
# Processing Record 49 of Set 12 | venice
# Processing Record 0 of Set 13 | amazar
# Processing Record 1 of Set 13 | ulfborg
# Processing Record 2 of Set 13 | poum
# Processing Record 3 of Set 13 | beringovskiy
# Processing Record 4 of Set 13 | tilichiki
# Processing Record 5 of Set 13 | bozeman
# Processing Record 6 of Set 13 | veseloyarsk
# Processing Record 7 of Set 13 | fairbanks
# Processing Record 8 of Set 13 | krasnovka
# Processing Record 9 of Set 13 | bitkine
# Processing Record 10 of Set 13 | togur
# Processing Record 11 of Set 13 | port lincoln
# Processing Record 12 of Set 13 | canutama
# Processing Record 13 of Set 13 | buraydah
# Processing Record 14 of Set 13 | coahuayana
# Processing Record 15 of Set 13 | sandwick
# Processing Record 16 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 13 | vaitape
# Processing Record 18 of Set 13 | bousse
# Processing Record 19 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 13 | zabaykalsk
# Processing Record 21 of Set 13 | mhango
# Processing Record 22 of Set 13 | danielskuil
# Processing Record 23 of Set 13 | dali
# Processing Record 24 of Set 13 | kabinda
# Processing Record 25 of Set 13 | ixtapa
# Processing Record 26 of Set 13 | kavaratti
# Processing Record 27 of Set 13 | alamosa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
# Display sample data                      
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       hilo  19.7297 -155.0900     27.93        85           6        1.34
# 1    talnakh  69.4865   88.3972    -26.10        97          98        0.78
# 2  hithadhoo  -0.6000   73.0833     26.90        76          45        2.91
# 3    sorland  67.6670   12.6934      5.92        79          64       15.57
# 4     rawson -43.3002  -65.1023     15.85        71           6        5.87
#
#   Country        Date
# 0      US  1674438891
# 1      RU  1674438969
# 2      MV  1674438969
# 3      NO  1674438891
# 4      AR  1674438949

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

#Convert Date by Using pandas to_datetime
city_data_df['Date']= pd.to_datetime(city_data_df['Date'],unit='s').dt.strftime('%Y-%m-%d %H:%M')  

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             hilo  19.7297 -155.0900     27.93        85           6
# 1          talnakh  69.4865   88.3972    -26.10        97          98
# 2        hithadhoo  -0.6000   73.0833     26.90        76          45
# 3          sorland  67.6670   12.6934      5.92        79          64
# 4           rawson -43.3002  -65.1023     15.85        71           6
#
#          Wind Speed Country              Date
# City_ID
# 0              1.34      US  2023-01-23 01:54
# 1              0.78      RU  2023-01-23 01:56
# 2              2.91      MV  2023-01-23 01:56
# 3             15.57      NO  2023-01-23 01:54
# 4              5.87      AR  2023-01-23 01:55

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'],edgecolors="black",facecolors="steelblue")
plt.grid()
plt.title("City Max Latitude vs. Temperature (2023-01-22)",fontsize=13)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
plt.savefig("output_data/Fig1.png")
# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# Incorporate the other graph properties

plt.scatter(city_data_df['Lat'],city_data_df['Humidity'],edgecolors="black",facecolors="steelblue")
plt.grid()
plt.title("City Latitude vs. Humidity (2023-01-22)",fontsize=13)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'],edgecolors="black",facecolors="steelblue")
plt.grid()
plt.title("City Latitude vs. Cloudiness (2023-01-22)",fontsize=13)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'],edgecolors="black",facecolors="steelblue")
plt.grid()
plt.title("City Latitude vs. Wind Speed (2023-01-22)",fontsize=13)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def Linear_Regression(x_value, y_value, x_label, y_label,x_text,y_text):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    regress_values=x_value * slope + intercept
    line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
    print(f'The r-value is: {rvalue}')
    plt.scatter(x_value, y_value, color="#1f77b4",s=40)
    plt.plot(x_value, regress_values,color='red')
    plt.xlabel(f"{x_label}", fontsize =13)
    plt.ylabel(f"{y_label}", fontsize =13)
    #xmin, xmax = plt.xlim()
    #xtext = (xmin + xmax) // 2
    #ytext = slope*xtext + intercept
    
    plt.annotate(line_eq,(x_text,y_text), fontsize=14, color="red")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df[city_data_df["Lat"]>=0]
northern_hemi_df=northern_hemi_df.reset_index()
# Display sample data
northern_hemi_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         hilo  19.7297 -155.0900     27.93        85           6
# 1        1      talnakh  69.4865   88.3972    -26.10        97          98
# 2        3      sorland  67.6670   12.6934      5.92        79          64
# 3        8         tezu  27.9167   96.1667     17.14        28           7
# 4       11  clyde river  70.4692  -68.5914    -31.87        68         100
#
#    Wind Speed Country              Date
# 0        1.34      US  2023-01-23 01:54
# 1        0.78      RU  2023-01-23 01:56
# 2       15.57      NO  2023-01-23 01:54
# 3        0.41      IN  2023-01-23 01:56
# 4       11.32      CA  2023-01-23 01:56

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df[city_data_df["Lat"]<0]
southern_hemi_df=southern_hemi_df.reset_index()

# Display sample data
southern_hemi_df.head()
# Out:
#    City_ID            City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        2       hithadhoo  -0.6000  73.0833     26.90        76          45
# 1        4          rawson -43.3002 -65.1023     15.85        71           6
# 2        5     port alfred -33.5906  26.8910     21.21        96          62
# 3        6    punta arenas -53.1500 -70.9167     13.06        47           0
# 4        7  port elizabeth -33.9180  25.5701     21.84        92         100
#
#    Wind Speed Country              Date
# 0        2.91      MV  2023-01-23 01:56
# 1        5.87      AR  2023-01-23 01:55
# 2        3.59      ZA  2023-01-23 01:56
# 3        1.03      CL  2023-01-23 01:52
# 4        1.79      ZA  2023-01-23 01:56

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_value=northern_hemi_df["Lat"]
y_value=northern_hemi_df["Max Temp"]
x_label="Latitude"
y_label="Max Temperature(C)"
x_text=0
y_text=-30
Linear_Regression(x_value, y_value, x_label, y_label, x_text,y_text)
# Out:
# The r-value is: -0.8279942608007874

# %%
# Linear regression on Southern Hemisphere
x_value=southern_hemi_df["Lat"]
y_value=southern_hemi_df["Max Temp"]
x_label="Latitude"
y_label="Max Temperature(C)"
x_text=-55
y_text=30
Linear_Regression(x_value, y_value, x_label, y_label, x_text,y_text)
# Out:
# The r-value is: 0.3579850106846713

# %% [markdown]
# **On Northern Hemisphere:**
# - As latitude increases, the maximum temperature falls.(A positive coefficient sign).
# - Maximum temperature change per degree of latitude
#
# **On Southern Hemisphere:**
# - TAs latitude increases, the maximum temperature rises.(A negative coefficient sign).
#
#
# **Compare two Datasets:**
# - Two datasets show that the further away from the equator, the lower the maximum temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value=northern_hemi_df["Lat"]
y_value=northern_hemi_df["Humidity"]
x_label="Latitude"
y_label="Humidity"
x_text=50
y_text=20
Linear_Regression(x_value, y_value, x_label, y_label, x_text,y_text)
# Out:
# The r-value is: 0.3555848370447416

# %%
# Southern Hemisphere
x_value=southern_hemi_df["Lat"]
y_value=southern_hemi_df["Humidity"]
x_label="Latitude"
y_label="Humidity"
x_text=-55
y_text=20
Linear_Regression(x_value, y_value, x_label, y_label, x_text,y_text)
# Out:
# The r-value is: 0.4749225414513207

# %% [markdown]
# **Northern Hemisphere:**
#  -YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value=northern_hemi_df["Lat"]
y_value=northern_hemi_df["Cloudiness"]
x_label="Latitude"
y_label="Cloudiness"
x_text=50
y_text=30
Linear_Regression(x_value, y_value, x_label, y_label, x_text,y_text)
# Out:
# The r-value is: 0.30708245932092026

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_value=southern_hemi_df["Lat"]
y_value=southern_hemi_df["Cloudiness"]
x_label="Latitude"
y_label="Cloudiness"
x_text=-55
y_text=45
Linear_Regression(x_value, y_value, x_label, y_label, x_text,y_text)
# Out:
# The r-value is: 0.5206731133852999

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value=northern_hemi_df["Lat"]
y_value=northern_hemi_df["Wind Speed"]
x_label="Latitude"
y_label="Wind Speed"
x_text=0
y_text=17
Linear_Regression(x_value, y_value, x_label, y_label, x_text,y_text)
# Out:
# The r-value is: 0.17204555190275672

# %%
# Southern Hemisphere
x_value=southern_hemi_df["Lat"]
y_value=southern_hemi_df["Wind Speed"]
x_label="Latitude"
y_label="Wind Speed"
x_text=-20
y_text=7
Linear_Regression(x_value, y_value, x_label, y_label, x_text,y_text)
# Out:
# The r-value is: -0.25830752848725075

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
# northern Hemisphere

temp_value=northern_hemi_df["Max Temp"]
humidity_value=northern_hemi_df["Humidity"]
cloudiness_value=northern_hemi_df["Cloudiness"]
wind_value=northern_hemi_df["Wind Speed"]

(slope, intercept,hum_rvalue, pvalue, stderr)=st.linregress(humidity_value,temp_value)
humidity_regress_values= humidity_value * slope + intercept
humidity_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"  

(slope, intercept,clo_rvalue, pvalue, stderr)=st.linregress(cloudiness_value,temp_value)
cloudiness_regress_values=cloudiness_value * slope + intercept
cloudiness_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"  

(slope, intercept,rvalue, pvalue, stderr)=st.linregress(wind_value,temp_value)
wind_regress_values=wind_value * slope + intercept
wind_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}" 

hum_correlation = round(st.pearsonr(humidity_value,temp_value)[0],2)
clo_correlation = round(st.pearsonr(cloudiness_value,temp_value)[0],2)
win_correlation = round(st.pearsonr(wind_value,temp_value)[0],2)

print(f"The correlation coefficient between humidity and Max Temperature on Northern Hemisphere is {hum_correlation}.")
print(f"The correlation coefficient between Cloudiness and Max Temperature on Northern Hemisphere is {clo_correlation}.")
print(f"The correlation coefficient between Wind Speed and Max Temperature on Northern Hemisphere is {win_correlation}.")
print("-"*100)
print(f'The Humidity-Max Temperature on Northern Hemisphere r-value is: {hum_rvalue}')
print(f'The Cloudiness-Max Temperature Northern Hemisphere r-value is: {clo_rvalue}')
print(f'The Wind speed-Max Temperature Northern Hemisphere r-value is: {rvalue}')
print("-"*100)
plt.figure(figsize=(12, 3))

plt.subplot(1, 3, 1)               
plt.scatter(humidity_value, temp_value, color="#1f77b4",s=40)
plt.plot(humidity_value, humidity_regress_values,color='red')
plt.title('Humidity VS Max Temperature(Northern Hemisphere)', fontsize=8)
plt.ylabel('Temperature')
plt.xlabel('Humidity')
plt.annotate(humidity_eq,(20,-40), fontsize=10, color="red")

plt.subplot(1, 3, 2)  
plt.scatter(cloudiness_value, temp_value, color="#1f77b4",s=40)
plt.plot(cloudiness_value, cloudiness_regress_values,color='red')
plt.title('Cloudiness VS Max Temperature(Northern Hemisphere)', fontsize=8)
plt.ylabel('Temperature')
plt.xlabel('Cloudiness')
plt.annotate(cloudiness_eq,(20,-40), fontsize=10, color="red")

plt.subplot(1, 3, 3)  
plt.scatter(wind_value, temp_value, color="#1f77b4",s=40)
plt.plot(wind_value, wind_regress_values,color='red')
plt.title('Wind Speed VS Max Temperature(Northern Hemisphere)', fontsize=8)
plt.ylabel('Temperature')
plt.xlabel('Wind Speed')
plt.annotate(wind_eq,(5,-40), fontsize=10, color="red")
plt.tight_layout()
plt.show()




# Southern Hemisphere

temp_value=southern_hemi_df["Max Temp"]
humidity_value=southern_hemi_df["Humidity"]
cloudiness_value=southern_hemi_df["Cloudiness"]
wind_value=southern_hemi_df["Wind Speed"]

(slope, intercept,hum_rvalue, pvalue, stderr)=st.linregress(humidity_value,temp_value)
humidity_regress_values= humidity_value * slope + intercept
humidity_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"  

(slope, intercept,clo_rvalue, pvalue, stderr)=st.linregress(cloudiness_value,temp_value)
cloudiness_regress_values=cloudiness_value * slope + intercept
cloudiness_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"  

(slope, intercept,rvalue, pvalue, stderr)=st.linregress(wind_value,temp_value)
wind_regress_values=wind_value * slope + intercept
wind_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}" 

hum_correlation = round(st.pearsonr(humidity_value,temp_value)[0],2)
clo_correlation = round(st.pearsonr(cloudiness_value,temp_value)[0],2)
win_correlation = round(st.pearsonr(wind_value,temp_value)[0],2)

print(f"The correlation coefficient between humidity and Max Temperature on Southern Hemisphere is {hum_correlation}.")
print(f"The correlation coefficient between Cloudiness and Max Temperature is on Southern Hemisphere {clo_correlation}.")
print(f"The correlation coefficient between Wind Speed and Max Temperature is on Southern Hemisphere {win_correlation}.")
print("-"*100)
print(f'The Humidity-Max Temperature on Southern Hemisphere r-value is: {hum_rvalue}')
print(f'The Cloudiness-Max Temperature on Southern Hemisphere r-value is: {clo_rvalue}')
print(f'The Wind speed-Max Temperature on Southern Hemisphere r-value is: {rvalue}')
print("-"*100)
plt.figure(figsize=(12, 3))

plt.subplot(1, 3, 1)               
plt.scatter(humidity_value, temp_value, color="#1f77b4",s=40)
plt.plot(humidity_value, humidity_regress_values,color='red')
plt.title('Humidity VS Max Temperature(Southern Hemisphere)', fontsize=8)
plt.ylabel('Temperature')
plt.xlabel('Humidity')
plt.annotate(humidity_eq,(20,12), fontsize=10, color="red")

plt.subplot(1, 3, 2)  
plt.scatter(cloudiness_value, temp_value, color="#1f77b4",s=40)
plt.plot(cloudiness_value, cloudiness_regress_values,color='red')
plt.title('Cloudiness VS Max Temperature(Southern Hemisphere)', fontsize=8)
plt.ylabel('Temperature')
plt.xlabel('Cloudiness')
plt.annotate(cloudiness_eq,(20,10), fontsize=10, color="red")

plt.subplot(1, 3, 3)  
plt.scatter(wind_value, temp_value, color="#1f77b4",s=40)
plt.plot(wind_value, wind_regress_values,color='red')
plt.title('Wind Speed VS Max Temperature(Southern Hemisphere)', fontsize=8)
plt.ylabel('Temperature')
plt.xlabel('Wind Speed')
plt.annotate(wind_eq,(8,20), fontsize=10, color="red")
plt.tight_layout()
plt.show()
# Out:
# The correlation coefficient between humidity and Max Temperature on Northern Hemisphere is -0.37.
# The correlation coefficient between Cloudiness and Max Temperature on Northern Hemisphere is -0.17.
# The correlation coefficient between Wind Speed and Max Temperature on Northern Hemisphere is 0.0.
# ----------------------------------------------------------------------------------------------------
# The Humidity-Max Temperature on Northern Hemisphere r-value is: -0.3713161623818346
# The Cloudiness-Max Temperature Northern Hemisphere r-value is: -0.17470345819212274
# The Wind speed-Max Temperature Northern Hemisphere r-value is: 0.002242030337942917
# ----------------------------------------------------------------------------------------------------
# The correlation coefficient between humidity and Max Temperature on Southern Hemisphere is -0.45.
# The correlation coefficient between Cloudiness and Max Temperature is on Southern Hemisphere -0.02.
# The correlation coefficient between Wind Speed and Max Temperature is on Southern Hemisphere 0.11.
# ----------------------------------------------------------------------------------------------------
# The Humidity-Max Temperature on Southern Hemisphere r-value is: -0.4453611703836534
# The Cloudiness-Max Temperature on Southern Hemisphere r-value is: -0.020412771867495717
# The Wind speed-Max Temperature on Southern Hemisphere r-value is: 0.10818975226563791
# ----------------------------------------------------------------------------------------------------
